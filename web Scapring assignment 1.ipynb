# %%
#write a python program to display all the header tags from 'en.wikipedia.org/wiki/main_page'.
# !pip install bs4
# !pip install html5lib
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page')
soup=BeautifulSoup(page.text, 'html.parser')
header=soup.find_all(['h1','h2','h3'])
for i in story:
   print(i)
# Out:
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
# ...

# %%
#Question 4(Book page)
Page = requests.get("https://bookpage.com/reviews")
Page
Page.content
soup = BeautifulSoup(Page.content)
soup
first_title=soup.find('div',class_="flex-article-content")
first_title
book_titles=[]
for i in titles:
    book_titles.append (i.text)
book_titles
first_author=soup.find('div',class_="flex-article-content")
first_author
first_author.text
book_titles=[]
for i in titles:
    book_titles.append(i.text.replace("\n",''))
book_titles
first_genre=soup.find('div',class_="genre-links hidden-phone")
first_genre
first_genre.text
book_authors=[]
for i in authors:
    book_authors.append (i.text)
book_authors
first_review=soup.find('a',class_="reviews?book_genre=fiction&amp;page=1")
first_review
first_review.text
book_authors=[]
for i in authors:
    book_authors.append (i.text.replace("\n",''))
book_authors  
len(book_titles)

books=pd.DataFrame({})
books['title']=book_titles
books['author']=book_authors
books['genre']=book_genres
books['review']=book_reviews
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>Book Reviews | BookPage</title>\n<meta name="description" content="Book recommendations of the best new books by genre and more.">\n<meta name="keywords" content="book reviews, books and literature, writing and writers">\n<link rel="canonical" href="https://bookpage.com/reviews">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="Book Reviews">\n<meta property="og:description" content="Book recommendations of the best new books by genre and more.">\n<meta property="og:type" content="website">\n<meta property="og:url" content="https://bookpage.com/reviews">\n<meta property="og:image" content="//www.bookpage.com/default_image.jpg">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" content="@bookpage">\n<meta name="twitter:creator" content="@bookpage">\n<meta name="robots" con
# ...

# %%
#question 8-(weather forcasting)
page = requests.get("https://www.weather.gov/","https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YNNFoL4zbX4")
soup = BeautifulSoup(page.content,"html.parser")
print(soup.find_all('a'))
week=soup.find(id='seven-day-forecast-body')
items=week.find_all(class_="tombstone-container")
# Out:
# [<a class="header-nws" href="http://www.weather.gov"><img alt="National Weather Service" src="/css/images/header.png"/></a>, <a class="header-doc" href="http://www.commerce.gov"><img alt="United States Department of Commerce" src="/css/images/header_doc.png"/></a>, <a class="header-noaa" href="http://www.noaa.gov" title="National Oceanic and Atmospheric Administration"></a>, <a href="#" onclick="goBack();">HOME</a>, <a href="http://www.weather.gov/forecastmaps">FORECAST</a>, <a href="http://www.weather.gov">Local</a>, <a href="http://digital.weather.gov">Graphical</a>, <a href="http://www.aviationweather.gov/">Aviation</a>, <a href="http://www.weather.gov/marine">Marine</a>, <a href="http://water.weather.gov/ahps/">Rivers and Lakes</a>, <a href="http://www.nhc.noaa.gov/">Hurricanes</a>, <a href="http://www.spc.noaa.gov/">Severe Weather</a>, <a href="http://www.weather.gov/fire/">Fire Weather</a>, <a href="https://www.esrl.noaa.gov/gmd/grad/solcalc/sunrise.html">Sun/Moon</a>, <a href=
# ...

# %%
#question 2 Hollywood Movie IMDB
url = 'https://www.imdb.com/find?q=2021%20movies&s=tt&ref_=fn_al_tt_mr'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

titles = [] 
for h3 in soup.find_all('h3'):
  titles.append(h3.string.strip())

ratings = []
for rating in soup.select('span.rating'):
  ratings.append(rating.string.strip())

lengths = []
for length in soup.select('span.length'):
  lengths.append(length.string.strip())

years = []
for year in soup.select('span.year'):
  years.append(year.string.strip())

 
with open('top100', 'w') as file:
    writer = csv.writer(file, delimiter=',')
    pd.DataFrame({})
  writer.writerow(["title", "ratings",  "year"])
    for i in range(100):
    writer.writerow([
      titles[i], 
      ratings[i], 
      lengths[i], 
      years[i], 
      
    ])

# %%
#question 3-(100 Hindi IMDB)
Page = requests.get("https://www.imdb.com/india/top-rated-indian-movies/")
Page
Page.content
soup = BeautifulSoup(Page.content,'lxml')
soup

titles = [] 
for h3 in soup.find_all('h3'):
  titles.append(h3.string.strip())

ratings = []
for rating in soup.select('span.rating'):
  ratings.append(rating.string.strip())

lengths = []
for length in soup.select('span.length'):
  lengths.append(length.string.strip())

years = []
for year in soup.select('span.year'):
  years.append(year.string.strip())

 
with open('top100', 'w') as file:
    writer = csv.writer(file, delimiter=',')

pd.DataFrame({})
  writer.writerow(["title", "ratings",  "year"])
    for i in range(100):
    writer.writerow([
      titles[i], 
      ratings[i], 
      lengths[i], 
      years[i], 
      
    ])

# %%
#ICC-CRICKET MENS
Page = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting",
    "https://www.icc-cricket.com/rankings/mens/player-rankings/test/bowling",
    "https://www.icc-cricket.com/rankings/mens/rankings-predictor/odi")
Page
Page.content
soup = BeautifulSoup(Page.content)
soup

# %%
for page in pages:
    request_object=requests.get(url,headers=headers)
soup_object=BeautifulSoup(html_content,"lxml")
for element in soup_object.select('[class+"ranking-pos up"],[class="ranking-pos down"]'):
        element.replace_with(BeautifulSoup("<"+elemnt.name+">"/+element.name+">","html.parser"))
rankling_type=soup_object.select_one("ranking_block_title_container>h4").text
result_file_name=ranking_type+".csv"
    
column_name=["player Name","Team Name","Rating","Career Best Rating"]
    pd.DataFrame({})

for element in soup_object.select('table[class="table ranking-table"]tr')
 if (element.find("th")):
        continue
        data_dict=dict()
        data_dict["crawl URl"]=url
        data_dict["Ranking Type"]=ranking_type
        if(element.select_one('[class*="position"]')):
            data_dict["podition"]=element.select_one('[class*="postion"]').text

# %%
#ICC-CRICKET WOMENS
page=["https://www.icc-cricket.com/rankings/womens/team-rankings/odi",
    "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting",
    "https://www.icc-cricket.com/rankings/womens/player-rankings/odi"]
Page
Page.content
soup = BeautifulSoup(Page.content)
soup

# %%
for page in pages:
    request_object=requests.get(url,headers=headers)
soup_object=BeautifulSoup(html_content,"lxml")
for element in soup_object.select('[class+"ranking-pos up"],[class="ranking-pos down"]'):
        element.replace_with(BeautifulSoup("<"+elemnt.name+">"/+element.name+">","html.parser"))
rankling_type=soup_object.select_one("ranking_block_title_container>h4").text
result_file_name=ranking_type+".csv"
    
column_name=["player Name","Team Name","Rating","Career Best Rating"]
    pd.DataFrame({})

for element in soup_object.select('table[class="table ranking-table"]tr')
 if (element.find("th")):
        continue
        data_dict=dict()
        data_dict["crawl URl"]=url
        data_dict["Ranking Type"]=ranking_type
        if(element.select_one('[class*="position"]')):
            data_dict["podition"]=element.select_one('[class*="postion"]').text

# %%
#Question 8(Amazon.in mobile under Rs.20000 )
Page=requests.get("https://www.amazon.in/s?k=under+20000+mobile&crid=1SZXKVA79LZXZ&sprefix=under+20000+%2Caps%2C1349&ref=nb_sb_ss_ts-doa-p_4_1s")
Page
Page.content
soup = BeautifulSoup(Page.content)
soup
title = soup.find("span", attrs={"id":'productTitle'})
title_value = title.string
def get_title(soup):
     
    try:
           title = soup.find("span", attrs={"id":'productTitle'})
 
              title_value = title.string
 
               title_string = title_value.strip()
 
    except AttributeError:
        title_string = ""   
 
    return title_string
def get_Avarage rating(soup):
 
    try:
        Avarage rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            Avarage rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating

    print("Product Name =", get_title(soup))
    print("Product Price =", get_price(soup))
    print("Product Avarage Rating =", get_rating(soup))
    print()

# %%
#Question 9(Internshala)
Page =requests.get("https://internshala.com/fresher-jobs")
Page
Page.content
soup=BeautifulSoup(Page.content)
soup
first_title=soup.find('div',class_="heading_4_5 profile")
first_title
first_title.text.replace('\n','')
job_titles=[]
for i in titles:
    job_titles.append(i.text)
job_titles
first_company=soup.find('a',class_="link_display_like_text")
first_company
first_company.text
first_company.text.replace('\n','')
companies=soup.find_all('a',class_="link_display_like_text")
companies
company_names=[]
for i in companies:
    company_names.appned(i.text(strip())
company_names
first_Date=soup.find('div',class_="other_detail_item")
first_Date
first_Date.text.replace('\n','')
Dates=soup.find_all('div',class_="other_detail_item")
Dates
job_Dates=[]
for i in Dates:
    job_Dates.append(i.text)
job_Dates
first_CTC=soup.find('i',class_="ic-16-money")
first_CTC
first_CTC.text
titles=soup.find_all('div',class_="heading_4_5 profile")
titles
 job_Dates=[]
for i in Dates:
    job_Dates.append(i.text.replace("\n",''))
job_Dates
jobs['titles']=job_titles
jobs['company']=comapny_names
Jobs['Date and CTC']=Date and CTC_list

# %%
#Question 10-(NoBrokers)
Page =requests.get("https://www.nobroker.in/property/sale/bangalore/Electronic%20City?type=BHK4&searchParam=W3sibGF0IjoxMi44NDUyMTQ1LCJsb24iOjc3LjY2MDE2OTUsInBsYWNlSWQiOiJDaElKdy1GUWQ0cHNyanNSSGZkYXpnXzhYRW8iLCJwbGFjZU5hbWUiOiJFbGVjdHJvbmljIENpdHkifV0=&propertyAge=0&radius=2.0%22")
Page
soup=BeautifulSoup(Page.content)
soup
house_title=soup.find('div',class_="nb-css-dvua67-singleValue nb-select__single-value ")
house_title
house_title.text
house_title.text.replace('\n','')
area_location=soup('div',class_="search-input-wrapper")
area_location
area_location.text
area.location.text.replace('\n','')
first_emi=soup.find('i',class_="ic-16-currency-inr")
first_emi
first_price=soup.find('i',class_="nb-select form-group nb-select__lg")
first_price
